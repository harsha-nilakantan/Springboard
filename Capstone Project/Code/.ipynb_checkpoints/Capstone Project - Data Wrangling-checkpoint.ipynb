# %% [markdown]
# # 4.3 Capstone Project - Data Wrangling: Spotify Data of 130k Songs
# ***
# This notebook will work through the initial exploration of the Spotify data set.

# %% [markdown]
# ### Imports and Data Read

# %%
# Imports

# imports for generic processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# imports for Spotify connection
import os
import sys
import json
import spotipy
import webbrowser
import spotipy.util as util

# %%
# reading the input Spotify data from tsv

df = pd.read_csv('C:\\Users\\Harsha Neel\\Documents\\GitHub\\Springboard\\Capstone Data\\songDB.tsv', sep = '\t', engine='python')
print("\n", df.head())
print("\n", df.shape)
print("\n", df.columns)
# Out:
#             Name  Danceability  Energy   Key  Loudness  Mode  Speechness  \
# 0    YuveYuveYu         0.624   0.857  10.0    -6.250   0.0      0.0542
# 1   Gloryhammer         0.517   0.916   0.0    -4.933   1.0      0.0559
# 2        Nostos         0.251   0.894   8.0    -4.103   0.0      0.0570
# 3     Yggdrasil         0.469   0.743   1.0    -5.570   0.0      0.0272
# 4  Incense&Iron         0.487   0.952   1.0    -4.429   0.0      0.0613
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo            Type  \
# 0      0.020800          0.206000     0.110    0.324  131.926  audio_features
# 1      0.000182          0.001910     0.306    0.444  135.996  audio_features
# 2      0.014400          0.000000     0.123    0.297  114.223  audio_features
# 3      0.002220          0.000111     0.276    0.481   86.953  audio_features
# 4      0.000228          0.000000     0.161    0.329  125.993  audio_features
#
#                        ID                                   Uri  \
# 0  6J2VvzKwWc2f0JP5RQVZjq  spotify:track:6J2VvzKwWc2f0JP5RQVZjq
# 1  4HA34COgxgVJ6zK88UN4Ik  spotify:track:4HA34COgxgVJ6zK88UN4Ik
# 2  3W6Xik6Xxf06JuUoZSATlD  spotify:track:3W6Xik6Xxf06JuUoZSATlD
# 3  2gGveBaLJQMtJ43X4UL5kH  spotify:track:2gGveBaLJQMtJ43X4UL5kH
# 4  1lRF81A1C9QoCgBcEop2zg  spotify:track:1lRF81A1C9QoCgBcEop2zg
#
#                                            Ref_Track  \
# 0  https://api.spotify.com/v1/tracks/6J2VvzKwWc2f...
# 1  https://api.spotify.com/v1/tracks/4HA34COgxgVJ...
# 2  https://api.spotify.com/v1/tracks/3W6Xik6Xxf06...
# 3  https://api.spotify.com/v1/tracks/2gGveBaLJQMt...
# 4  https://api.spotify.com/v1/tracks/1lRF81A1C9Qo...
#
#                                         URL_features  Duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6J2V...     282920.0
# 1  https://api.spotify.com/v1/audio-analysis/4HA3...     300320.0
# 2  https://api.spotify.com/v1/audio-analysis/3W6X...     175353.0
# 3  https://api.spotify.com/v1/audio-analysis/2gGv...     272292.0
# 4  https://api.spotify.com/v1/audio-analysis/1lRF...     237933.0
#
#   time_signature        Genre
# 0            4.0  celticmetal
# 1            4.0  celticmetal
# 2            4.0  celticmetal
# 3            4.0  celticmetal
# 4            4.0  celticmetal
#
#  (131580, 20)
#
#  Index(['Name', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode',
#        'Speechness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence',
#        'Tempo', 'Type', 'ID', 'Uri', 'Ref_Track', 'URL_features',
#        'Duration_ms', 'time_signature', 'Genre'],
#       dtype='object')

# %%
# Cleaning up data - removing unnecessary columns, index by track ID etc.

# index by track ID
df_cleaned = df.set_index('ID')

df_cleaned = df_cleaned.drop(['Type', 'Uri', 'Ref_Track', 'URL_features'], axis=1)
print("\n", df_cleaned.head())
print("\n", df_cleaned.shape)
print("\n", df_cleaned.columns)

# Checking for Null entries
nulls = df_cleaned.columns[df_cleaned.isnull().any()]
print("\nColumns with Nulls are: \n", df_cleaned[nulls].isnull().sum())
# Out:
#                                  Name  Danceability  Energy   Key  Loudness  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq    YuveYuveYu         0.624   0.857  10.0    -6.250
# 4HA34COgxgVJ6zK88UN4Ik   Gloryhammer         0.517   0.916   0.0    -4.933
# 3W6Xik6Xxf06JuUoZSATlD        Nostos         0.251   0.894   8.0    -4.103
# 2gGveBaLJQMtJ43X4UL5kH     Yggdrasil         0.469   0.743   1.0    -5.570
# 1lRF81A1C9QoCgBcEop2zg  Incense&Iron         0.487   0.952   1.0    -4.429
#
#                         Mode  Speechness  Acousticness  Instrumentalness  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq   0.0      0.0542      0.020800          0.206000
# 4HA34COgxgVJ6zK88UN4Ik   1.0      0.0559      0.000182          0.001910
# 3W6Xik6Xxf06JuUoZSATlD   0.0      0.0570      0.014400          0.000000
# 2gGveBaLJQMtJ43X4UL5kH   0.0      0.0272      0.002220          0.000111
# 1lRF81A1C9QoCgBcEop2zg   0.0      0.0613      0.000228          0.000000
#
#                         Liveness  Valence    Tempo  Duration_ms  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq     0.110    0.324  131.926     282920.0
# 4HA34COgxgVJ6zK88UN4Ik     0.306    0.444  135.996     300320.0
# 3W6Xik6Xxf06JuUoZSATlD     0.123    0.297  114.223     175353.0
# 2gGveBaLJQMtJ43X4UL5kH     0.276    0.481   86.953     272292.0
# 1lRF81A1C9QoCgBcEop2zg     0.161    0.329  125.993     237933.0
#
#                        time_signature        Genre
# ID
# 6J2VvzKwWc2f0JP5RQVZjq            4.0  celticmetal
# 4HA34COgxgVJ6zK88UN4Ik            4.0  celticmetal
# 3W6Xik6Xxf06JuUoZSATlD            4.0  celticmetal
# 2gGveBaLJQMtJ43X4UL5kH            4.0  celticmetal
# 1lRF81A1C9QoCgBcEop2zg            4.0  celticmetal
#
#  (131580, 15)
#
#  Index(['Name', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode',
#        'Speechness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence',
#        'Tempo', 'Duration_ms', 'time_signature', 'Genre'],
#       dtype='object')
#
# Columns with Nulls are:
#  Name      2
# Genre    26
# dtype: int64

# %%
### We see that there are some null entries. We need to examine this further.
### There are even 2 null song names, presumably missing from the "Name" column. These will need to be cleaned up.

print(df_cleaned[df_cleaned['Name'].isnull()])
print(df_cleaned[df_cleaned['Genre'].isnull()])
# Out:
#                        Name  Danceability  Energy  Key  Loudness  Mode  \
# ID
# 1PAhQVE5h3LKkEpdaTdpjq  NaN         0.714   0.839  1.0    -7.668   0.0
# 1PAhQVE5h3LKkEpdaTdpjq  NaN         0.714   0.839  1.0    -7.668   0.0
#
#                         Speechness  Acousticness  Instrumentalness  Liveness  \
# ID
# 1PAhQVE5h3LKkEpdaTdpjq      0.0401       0.00237          0.000007    0.0795
# 1PAhQVE5h3LKkEpdaTdpjq      0.0401       0.00237          0.000007    0.0795
#
#                         Valence   Tempo  Duration_ms time_signature  \
# ID
# 1PAhQVE5h3LKkEpdaTdpjq    0.614  98.003     237551.0            4.0
# 1PAhQVE5h3LKkEpdaTdpjq    0.614  98.003     237551.0            4.0
#
#                              Genre
# ID
# 1PAhQVE5h3LKkEpdaTdpjq  balkantrap
# 1PAhQVE5h3LKkEpdaTdpjq  balkantrap
#                                        Name  Danceability  Energy     Key  \
# ID
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX  0.325         0.315     3.0 -12.236
# spotify:track:2XwMxGJOluHPqEJLN2vdTs  0.502         0.914     5.0  -9.136
# spotify:track:1zCvKrrtCvH50VtagvUsNA  0.511         0.326     2.0  -9.397
# spotify:track:6gJxXGTn7kRXKb9aFGnQ9n  0.411         0.595     0.0  -9.512
# spotify:track:08ZhPd0sS0DFxor1icBSHr  0.309         0.784     0.0  -8.174
# spotify:track:1n1nfYSCem40sVcjrWtNyL  0.564         0.484     5.0  -5.824
# spotify:track:2AjStNCJyvn8wvyOsBTtOR  0.608         0.774     4.0  -5.048
# spotify:track:3BaMpfFx9wCAz1eOoDgJdm  0.501         0.468     9.0  -4.491
# spotify:track:3mBwcEWG9YQsx4TzmiktNb  0.471         0.387     4.0  -7.223
# spotify:track:0woSKRWOhPEa7bpUXZOhF8  0.695         0.935     9.0  -2.583
# spotify:track:00Kx4C18i4f60gtqhI6cEs  0.759         0.604     1.0  -6.319
# spotify:track:3lXaXiHH2v0Qm2NXfdKhzD  0.748         0.959     0.0  -3.613
# spotify:track:7EgX6jDHNz6tryEx1iZ25O   0.74         0.794     1.0  -4.357
# spotify:track:0JN8LCqXsqyeedSAHhzaBd  0.446         0.531     2.0  -6.120
# spotify:track:01OWLju63QtwxardhpliQs   0.43         0.448     4.0  -8.220
# spotify:track:6DUJKGaQtjZO7e1BlVoT6l  0.554         0.577     4.0  -6.625
# spotify:track:3TlfZHGwF6PnRuL6MVJon3  0.519         0.442     5.0  -6.318
# spotify:track:6Uq4ZhUWvgjxqEzLZOMmqS  0.421         0.488     7.0  -9.056
# spotify:track:7lHTjGxsNQ2EFZJqJPn65S  0.643         0.875    11.0  -5.048
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX  0.325         0.315     3.0 -12.236
# spotify:track:1zCvKrrtCvH50VtagvUsNA  0.511         0.326     2.0  -9.397
# spotify:track:02p5yMOb2ayMq9rGkYV8md  0.667         0.873     9.0  -4.709
# spotify:track:5dYIraiPubueMqlW47ZqBV  0.772         0.295     8.0 -14.372
# spotify:track:7yqiIvuaWEubrFoxLVDEbt  0.694         0.680    11.0  -9.818
# spotify:track:4jWrBoaAQoiq0kxZS6Ne8T  0.473         0.882     1.0  -4.199
# spotify:track:55yEGTrCj2qhBWN8BBWdRf  0.479         0.695     5.0  -8.768
#
#                                       Loudness    Mode  Speechness  \
# ID
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX       1.0  0.0365     0.93300
# spotify:track:2XwMxGJOluHPqEJLN2vdTs       0.0  0.0527     0.25100
# spotify:track:1zCvKrrtCvH50VtagvUsNA       1.0  0.0347     0.76400
# spotify:track:6gJxXGTn7kRXKb9aFGnQ9n       1.0  0.0469     0.02340
# spotify:track:08ZhPd0sS0DFxor1icBSHr       1.0  0.1080     0.00181
# spotify:track:1n1nfYSCem40sVcjrWtNyL       0.0  0.0293     0.85300
# spotify:track:2AjStNCJyvn8wvyOsBTtOR       0.0  0.0297     0.55100
# spotify:track:3BaMpfFx9wCAz1eOoDgJdm       1.0  0.0270     0.86800
# spotify:track:3mBwcEWG9YQsx4TzmiktNb       1.0  0.0276     0.92800
# spotify:track:0woSKRWOhPEa7bpUXZOhF8       0.0  0.0376     0.09670
# spotify:track:00Kx4C18i4f60gtqhI6cEs       0.0  0.0424     0.61500
# spotify:track:3lXaXiHH2v0Qm2NXfdKhzD       1.0  0.0394     0.53600
# spotify:track:7EgX6jDHNz6tryEx1iZ25O       0.0  0.0391     0.11500
# spotify:track:0JN8LCqXsqyeedSAHhzaBd       0.0  0.0356     0.83300
# spotify:track:01OWLju63QtwxardhpliQs       1.0  0.0274     0.38800
# spotify:track:6DUJKGaQtjZO7e1BlVoT6l       1.0  0.0329     0.42800
# spotify:track:3TlfZHGwF6PnRuL6MVJon3       0.0  0.0257     0.83100
# spotify:track:6Uq4ZhUWvgjxqEzLZOMmqS       0.0  0.0295     0.65300
# spotify:track:7lHTjGxsNQ2EFZJqJPn65S       0.0  0.0306     0.08480
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX       1.0  0.0365     0.93300
# spotify:track:1zCvKrrtCvH50VtagvUsNA       1.0  0.0347     0.76400
# spotify:track:02p5yMOb2ayMq9rGkYV8md       1.0  0.1990     0.08720
# spotify:track:5dYIraiPubueMqlW47ZqBV       1.0  0.4680     0.18300
# spotify:track:7yqiIvuaWEubrFoxLVDEbt       1.0  0.1090     0.16000
# spotify:track:4jWrBoaAQoiq0kxZS6Ne8T       1.0  0.3700     0.00753
# spotify:track:55yEGTrCj2qhBWN8BBWdRf       0.0  0.0385     0.14700
#
#                                       Acousticness  Instrumentalness  \
# ID
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX      0.022800            0.1190
# spotify:track:2XwMxGJOluHPqEJLN2vdTs      0.000000            0.3930
# spotify:track:1zCvKrrtCvH50VtagvUsNA      0.000000            0.2840
# spotify:track:6gJxXGTn7kRXKb9aFGnQ9n      0.000000            0.1070
# spotify:track:08ZhPd0sS0DFxor1icBSHr      0.000000            0.1280
# spotify:track:1n1nfYSCem40sVcjrWtNyL      0.000001            0.0928
# spotify:track:2AjStNCJyvn8wvyOsBTtOR      0.000000            0.0935
# spotify:track:3BaMpfFx9wCAz1eOoDgJdm      0.000000            0.1540
# spotify:track:3mBwcEWG9YQsx4TzmiktNb      0.000073            0.1040
# spotify:track:0woSKRWOhPEa7bpUXZOhF8      0.000000            0.2160
# spotify:track:00Kx4C18i4f60gtqhI6cEs      0.000003            0.0335
# spotify:track:3lXaXiHH2v0Qm2NXfdKhzD      0.000038            0.0735
# spotify:track:7EgX6jDHNz6tryEx1iZ25O      0.000000            0.1060
# spotify:track:0JN8LCqXsqyeedSAHhzaBd      0.000000            0.2230
# spotify:track:01OWLju63QtwxardhpliQs      0.000048            0.1110
# spotify:track:6DUJKGaQtjZO7e1BlVoT6l      0.000000            0.1060
# spotify:track:3TlfZHGwF6PnRuL6MVJon3      0.000000            0.1250
# spotify:track:6Uq4ZhUWvgjxqEzLZOMmqS      0.000134            0.1400
# spotify:track:7lHTjGxsNQ2EFZJqJPn65S      0.014000            0.3190
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX      0.022800            0.1190
# spotify:track:1zCvKrrtCvH50VtagvUsNA      0.000000            0.2840
# spotify:track:02p5yMOb2ayMq9rGkYV8md      0.000311            0.2370
# spotify:track:5dYIraiPubueMqlW47ZqBV      0.000000            0.1290
# spotify:track:7yqiIvuaWEubrFoxLVDEbt      0.000596            0.8490
# spotify:track:4jWrBoaAQoiq0kxZS6Ne8T      0.000000            0.3620
# spotify:track:55yEGTrCj2qhBWN8BBWdRf      0.000000            0.1340
#
#                                       Liveness  Valence           Tempo  \
# ID
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX     0.413  108.899  audio_features
# spotify:track:2XwMxGJOluHPqEJLN2vdTs     0.554  110.207  audio_features
# spotify:track:1zCvKrrtCvH50VtagvUsNA     0.485  115.573  audio_features
# spotify:track:6gJxXGTn7kRXKb9aFGnQ9n     0.634  132.775  audio_features
# spotify:track:08ZhPd0sS0DFxor1icBSHr     0.942  170.542  audio_features
# spotify:track:1n1nfYSCem40sVcjrWtNyL     0.145   95.025  audio_features
# spotify:track:2AjStNCJyvn8wvyOsBTtOR     0.449  117.030  audio_features
# spotify:track:3BaMpfFx9wCAz1eOoDgJdm     0.374  159.970  audio_features
# spotify:track:3mBwcEWG9YQsx4TzmiktNb     0.429  129.881  audio_features
# spotify:track:0woSKRWOhPEa7bpUXZOhF8     0.415  112.004  audio_features
# spotify:track:00Kx4C18i4f60gtqhI6cEs     0.623  104.981  audio_features
# spotify:track:3lXaXiHH2v0Qm2NXfdKhzD     0.834  118.012  audio_features
# spotify:track:7EgX6jDHNz6tryEx1iZ25O     0.848  112.998  audio_features
# spotify:track:0JN8LCqXsqyeedSAHhzaBd     0.459  187.827  audio_features
# spotify:track:01OWLju63QtwxardhpliQs     0.237  163.638  audio_features
# spotify:track:6DUJKGaQtjZO7e1BlVoT6l     0.273  139.968  audio_features
# spotify:track:3TlfZHGwF6PnRuL6MVJon3     0.344   93.931  audio_features
# spotify:track:6Uq4ZhUWvgjxqEzLZOMmqS     0.263   81.951  audio_features
# spotify:track:7lHTjGxsNQ2EFZJqJPn65S     0.770  139.039  audio_features
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX     0.413  108.899  audio_features
# spotify:track:1zCvKrrtCvH50VtagvUsNA     0.485  115.573  audio_features
# spotify:track:02p5yMOb2ayMq9rGkYV8md     0.491  146.037  audio_features
# spotify:track:5dYIraiPubueMqlW47ZqBV     0.311  132.020  audio_features
# spotify:track:7yqiIvuaWEubrFoxLVDEbt     0.284  120.007  audio_features
# spotify:track:4jWrBoaAQoiq0kxZS6Ne8T     0.374  108.824  audio_features
# spotify:track:55yEGTrCj2qhBWN8BBWdRf     0.549  116.966  audio_features
#
#                                       Duration_ms  time_signature Genre
# ID
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX          4.0      pianoblues  None
# spotify:track:2XwMxGJOluHPqEJLN2vdTs          4.0      raregroove  None
# spotify:track:1zCvKrrtCvH50VtagvUsNA          3.0         doo-wop  None
# spotify:track:6gJxXGTn7kRXKb9aFGnQ9n          4.0        germanoi  None
# spotify:track:08ZhPd0sS0DFxor1icBSHr          4.0        germanoi  None
# spotify:track:1n1nfYSCem40sVcjrWtNyL          4.0           v-pop  None
# spotify:track:2AjStNCJyvn8wvyOsBTtOR          4.0           v-pop  None
# spotify:track:3BaMpfFx9wCAz1eOoDgJdm          4.0           v-pop  None
# spotify:track:3mBwcEWG9YQsx4TzmiktNb          4.0           v-pop  None
# spotify:track:0woSKRWOhPEa7bpUXZOhF8          4.0           v-pop  None
# spotify:track:00Kx4C18i4f60gtqhI6cEs          4.0           v-pop  None
# spotify:track:3lXaXiHH2v0Qm2NXfdKhzD          4.0           v-pop  None
# spotify:track:7EgX6jDHNz6tryEx1iZ25O          4.0           v-pop  None
# spotify:track:0JN8LCqXsqyeedSAHhzaBd          3.0           v-pop  None
# spotify:track:01OWLju63QtwxardhpliQs          3.0     newromantic  None
# spotify:track:6DUJKGaQtjZO7e1BlVoT6l          4.0     newromantic  None
# spotify:track:3TlfZHGwF6PnRuL6MVJon3          4.0     newromantic  None
# spotify:track:6Uq4ZhUWvgjxqEzLZOMmqS          4.0     newromantic  None
# spotify:track:7lHTjGxsNQ2EFZJqJPn65S          4.0         europop  None
# spotify:track:4sAFYSEg5XV6WOlOeCnXfX          4.0      pianoblues  None
# spotify:track:1zCvKrrtCvH50VtagvUsNA          3.0         doo-wop  None
# spotify:track:02p5yMOb2ayMq9rGkYV8md          4.0  undergroundrap  None
# spotify:track:5dYIraiPubueMqlW47ZqBV          4.0  undergroundrap  None
# spotify:track:7yqiIvuaWEubrFoxLVDEbt          4.0  undergroundrap  None
# spotify:track:4jWrBoaAQoiq0kxZS6Ne8T          4.0  undergroundrap  None
# spotify:track:55yEGTrCj2qhBWN8BBWdRf          4.0       freakbeat  None

# %%
### For the Name column, we see that the names themselves are missing. These 2 records can be dropped safely.

### For the records with the Null "Genre"column, these are probably null because the track IDs were not 
### formatted correctly when the data set was built. Given that we are not about to download Genre information
### from Spotify, these cannot be resupplied or repaired. So we will drop them as well from the dataset.

df_cleaned = df_cleaned.dropna()

print(df_cleaned.shape)
print(df_cleaned.isnull().any())

# Check for any duplicates
print(df_cleaned[df_cleaned.duplicated()].head())

# Removing duplicates
df_cleaned = df_cleaned.drop_duplicates()

print(df_cleaned.shape)
# Out:
# (131552, 15)
# Name                False
# Danceability        False
# Energy              False
# Key                 False
# Loudness            False
# Mode                False
# Speechness          False
# Acousticness        False
# Instrumentalness    False
# Liveness            False
# Valence             False
# Tempo               False
# Duration_ms         False
# time_signature      False
# Genre               False
# dtype: bool
#                                             Name  Danceability   Energy   Key  \
# ID
# 4qgDlkfqsbZ0q5tOSp0nqE             BloodofHeroes        0.5480  0.91800   4.0
# 3V417nSM4Ilh0Tt5CqustV                 Yggdrasil        0.4690  0.74300   1.0
# 1KuNk1ZZPTZKwjjo1Vdw9G         FireBloodandSteel        0.5410  0.91200   0.0
# 1Qf8YGAWyajekT32SDCpbB               IevanPolkka        0.5340  0.97200   0.0
# 02h7YFPYqyKtSx2eAwHmHZ               Waldschrein        0.3350  0.99200   7.0
# 5u3l2TONYacJgmRPQVaF9y   TwilightOfTheThunderGod        0.3740  0.92000   6.0
# 1kRuXopX9SPHrvTp1kIvpO                     Vodka        0.3530  0.96000   7.0
# 4SZymOV9M2wAz1N2uMWQUx                  InisMona        0.4300  0.99100   2.0
# 1zt3Jjw4kyyMXdSSWQbLI5         GreySublimeArchon        0.4590  0.99500   0.0
# 2JFnvk50eXQ5ukFCoUHgcr              Thousandfold        0.5210  0.98800   7.0
# 6AXaFon5l29UPFnDNr8u6i                 Helvetios        0.5210  0.99800   2.0
# 62LEQyUMcEv7YI2VAJdQ5Z             ARoseforEpona        0.4800  0.96900  11.0
# 0auFmAHLVYJqQ43ElC9XwH    UisElveti(Re-Recorded)        0.5440  0.95600   7.0
# 5xT2TAzbJf9kZkJh9qskwC                    Spirit        0.3730  0.94200   0.0
# 4inaFfvPzYE2s1N0rrFEuY                 Tegernakô        0.2100  0.97100   0.0
# 57RMsTZgk0UXn9jRLa950f                    Luxtos        0.2840  0.97400   2.0
# 0lxCFQuLwiKGsJOvcO7PxM              MeettheEnemy        0.5090  0.99600   3.0
# 5Fw8WbjW6ZWuMR6d9naYw5             ARoseforEpona        0.4800  0.96900  11.0
# 7LmyIBMl7ZCm17TBhzKb5Q                Otherworld        0.1950  0.26000   4.0
# 0g2X8EDZHpFuhrlYyZXUDM              Thousandfold        0.5210  0.98800   7.0
# 3bd4MYlPc6EdfY8f0WnWcO         TheArcaneDominion        0.2770  0.93600   7.0
# 0lmp8VSWPOyrlmYpjNNDhU                     Omnos        0.5420  0.94000   2.0
# 4MCLjQ7QFmPWYtLBeJlMRz        BloodstainedGround        0.4570  0.99800  11.0
# 4hNJXoAQeBtpSUF5MZtzre               SlaniasSong        0.4420  0.95900  10.0
# 4Q4xocsF5xlQDht25iHdkK                    Tarvos        0.4310  0.99600  11.0
# 3Mz5lXbMBK2tUmKAwAJwi1                    Gunman        0.3080  0.96500   8.0
# 5XupNatXG7LmrOwr5ezxzp                   Harmaja        0.4980  0.71500   7.0
# 2wm1p0qitm58cywbMjb9tX                Aallonalla        0.6110  0.91200   4.0
# 06C7xapNmwIj7y5WA4LLuz            DestinedCourse        0.5300  0.90700   7.0
# 5lizvEPQRY3P7KYVY434T2                     Drink        0.5090  0.85500   8.0
# ...                                          ...           ...      ...   ...
# 0vBF31MfEp7DDHHIfbxwIH                       Lux        0.1510  0.00678  10.0
# 1aa3A3F6b5FZFtXAhtrybK                TimeTravel        0.1200  0.05850   3.0
# 7gpL5CorPuYBthvZkPPFGd                 Glitching        0.1610  0.00613   0.0
# 75D9esOK7ASfcREQAvbtql                    Magica        0.0951  0.08720   7.0
# 53sNuDhuyhtVTPNXbk4dEN                Mind-Drift        0.1440  0.01510   8.0
# 30VnmNoXmeNMlDR6MxLP5U                   Threads        0.1200  0.04360   4.0
# 2IAZza3wdiTYT8QtO0hbLv                NewEndings        0.2260  0.03150   0.0
# 0yyWxyeHt09K786RjTs6KH             EscapeGravity        0.1500  0.05860   3.0
# 0bnRIsBDDT2GyEozHCOcie             Bio-Adoptions        0.1440  0.04180   0.0
# 4zI7J4c58Br1tY10NDyhlR               Scintillans        0.1910  0.01430   2.0
# 4bx9Lbbsb2VnHkxwqd3NQ1          FromtheOtherSide        0.1860  0.08900   2.0
# 5NRhAVJrW5o4FK1OKKgbgQ                 Lakeshore        0.6180  0.11600   2.0
# 3dKEGve9GLAg0q8REFQpgY                  Campanis        0.1280  0.07060   8.0
# 6LnG3cueIxb0SpZP3AfdUw                  Triangle        0.2790  0.00639   0.0
# 1CYtN9f8AgIbQpCbzCnMRq           EnchantedDreams        0.1670  0.18300  10.0
# 1VZmICoSKxQVj6DEOt0O0K                     Aware        0.1770  0.06180   3.0
# 23puVz6Rhiq8Wax9KxnZtW         TheHealingProcess        0.2410  0.05530   3.0
# 6l8Xxuu9DMIEzZqfvedNZA  RepetetiveChatteringMind        0.1540  0.22600   1.0
# 4RnDh1ovWF24qCsTma9pgV             LifeInReverse        0.1620  0.02910   0.0
# 1uO9ZJFzDuwQ2XzmHt5TmN               Incubations        0.1940  0.03880   2.0
# 3O9i7hYrsLU99msJcjPOCL              ShamanDreams        0.1610  0.07920   8.0
# 0IV0v2RIhevXsu9G0u82iP                 Underbart        0.1880  0.13900  10.0
# 6jJkW2RUsOHCe4hiIk1tED               QuietDreams        0.1880  0.02490  10.0
# 3qEJ0eRAf40TTrofN7rmP7      LapluiedeSaintMichel        0.1450  0.04030   9.0
# 0SEmfr0lcljA3KFZtAxto4                     Kyoto        0.1510  0.02440   6.0
# 6uZqFdxRsSXgswqtKKBYK7                 DeepDream        0.1790  0.09720   7.0
# 0OLknAPE9i8CXou7d9Hk4M         SpiritualConquest        0.1620  0.00532  11.0
# 72lTBttLvsJ7FXLhualmIN            PartsofReality        0.1640  0.00501  10.0
# 2gjiQzZogB3fp4V7t9GKBh                   Volveré        0.7460  0.85500   0.0
# 09QIIA0zY0dqRoovbsCdxE                   Háblame        0.3450  0.23800  10.0
#
#                         Loudness  Mode  Speechness  Acousticness  \
# ID
# 4qgDlkfqsbZ0q5tOSp0nqE    -5.730   0.0      0.0545      0.000035
# 3V417nSM4Ilh0Tt5CqustV    -5.570   0.0      0.0272      0.002220
# 1KuNk1ZZPTZKwjjo1Vdw9G    -5.491   1.0      0.0455      0.000093
# 1Qf8YGAWyajekT32SDCpbB    -4.309   1.0      0.0372      0.000045
# 02h7YFPYqyKtSx2eAwHmHZ    -3.034   1.0      0.1780      0.000136
# 5u3l2TONYacJgmRPQVaF9y    -4.653   1.0      0.0501      0.000016
# 1kRuXopX9SPHrvTp1kIvpO    -5.588   1.0      0.2270      0.000062
# 4SZymOV9M2wAz1N2uMWQUx    -2.837   0.0      0.0916      0.000343
# 1zt3Jjw4kyyMXdSSWQbLI5    -3.122   1.0      0.0938      0.000166
# 2JFnvk50eXQ5ukFCoUHgcr    -2.776   0.0      0.0756      0.063700
# 6AXaFon5l29UPFnDNr8u6i    -1.814   0.0      0.1440      0.000534
# 62LEQyUMcEv7YI2VAJdQ5Z    -2.742   0.0      0.0964      0.025900
# 0auFmAHLVYJqQ43ElC9XwH    -4.066   0.0      0.0356      0.000824
# 5xT2TAzbJf9kZkJh9qskwC    -5.743   1.0      0.0938      0.000468
# 4inaFfvPzYE2s1N0rrFEuY    -4.495   1.0      0.1070      0.000454
# 57RMsTZgk0UXn9jRLa950f    -2.409   0.0      0.1070      0.024600
# 0lxCFQuLwiKGsJOvcO7PxM    -2.542   0.0      0.1620      0.001430
# 5Fw8WbjW6ZWuMR6d9naYw5    -2.742   0.0      0.0964      0.025900
# 7LmyIBMl7ZCm17TBhzKb5Q   -16.213   0.0      0.0383      0.016800
# 0g2X8EDZHpFuhrlYyZXUDM    -2.776   0.0      0.0756      0.063700
# 3bd4MYlPc6EdfY8f0WnWcO    -4.689   0.0      0.0544      0.000045
# 0lmp8VSWPOyrlmYpjNNDhU    -2.430   0.0      0.0442      0.001100
# 4MCLjQ7QFmPWYtLBeJlMRz    -3.230   0.0      0.1860      0.000051
# 4hNJXoAQeBtpSUF5MZtzre    -3.201   0.0      0.0607      0.001180
# 4Q4xocsF5xlQDht25iHdkK    -2.705   0.0      0.1470      0.000072
# 3Mz5lXbMBK2tUmKAwAJwi1    -3.172   1.0      0.0591      0.000023
# 5XupNatXG7LmrOwr5ezxzp    -6.462   1.0      0.0298      0.089400
# 2wm1p0qitm58cywbMjb9tX    -5.106   0.0      0.0365      0.000515
# 06C7xapNmwIj7y5WA4LLuz    -6.117   1.0      0.0901      0.006930
# 5lizvEPQRY3P7KYVY434T2    -4.567   1.0      0.0460      0.000037
# ...                          ...   ...         ...           ...
# 0vBF31MfEp7DDHHIfbxwIH   -35.997   1.0      0.0587      0.936000
# 1aa3A3F6b5FZFtXAhtrybK   -27.623   1.0      0.0383      0.696000
# 7gpL5CorPuYBthvZkPPFGd   -38.027   1.0      0.0390      0.994000
# 75D9esOK7ASfcREQAvbtql   -24.168   1.0      0.0371      0.944000
# 53sNuDhuyhtVTPNXbk4dEN   -32.452   1.0      0.0397      0.984000
# 30VnmNoXmeNMlDR6MxLP5U   -22.044   1.0      0.0383      0.790000
# 2IAZza3wdiTYT8QtO0hbLv   -27.615   1.0      0.0340      0.989000
# 0yyWxyeHt09K786RjTs6KH   -28.755   1.0      0.0443      0.857000
# 0bnRIsBDDT2GyEozHCOcie   -26.223   1.0      0.0380      0.976000
# 4zI7J4c58Br1tY10NDyhlR   -27.967   1.0      0.0431      0.984000
# 4bx9Lbbsb2VnHkxwqd3NQ1   -27.017   1.0      0.0377      0.901000
# 5NRhAVJrW5o4FK1OKKgbgQ   -17.498   1.0      0.0344      0.476000
# 3dKEGve9GLAg0q8REFQpgY   -25.319   1.0      0.0481      0.993000
# 6LnG3cueIxb0SpZP3AfdUw   -32.406   1.0      0.0383      0.989000
# 1CYtN9f8AgIbQpCbzCnMRq   -20.844   0.0      0.0472      0.978000
# 1VZmICoSKxQVj6DEOt0O0K   -22.682   1.0      0.0433      0.942000
# 23puVz6Rhiq8Wax9KxnZtW   -23.605   1.0      0.0336      0.926000
# 6l8Xxuu9DMIEzZqfvedNZA   -19.430   1.0      0.0360      0.459000
# 4RnDh1ovWF24qCsTma9pgV   -27.488   1.0      0.0381      0.962000
# 1uO9ZJFzDuwQ2XzmHt5TmN   -28.622   0.0      0.0421      0.987000
# 3O9i7hYrsLU99msJcjPOCL   -28.714   1.0      0.0398      0.819000
# 0IV0v2RIhevXsu9G0u82iP   -21.075   1.0      0.0415      0.985000
# 6jJkW2RUsOHCe4hiIk1tED   -27.196   1.0      0.0373      0.988000
# 3qEJ0eRAf40TTrofN7rmP7   -28.710   1.0      0.0458      0.343000
# 0SEmfr0lcljA3KFZtAxto4   -32.248   0.0      0.0400      0.980000
# 6uZqFdxRsSXgswqtKKBYK7   -26.884   0.0      0.0481      0.991000
# 0OLknAPE9i8CXou7d9Hk4M   -36.770   1.0      0.0376      0.969000
# 72lTBttLvsJ7FXLhualmIN   -36.520   0.0      0.0445      0.990000
# 2gjiQzZogB3fp4V7t9GKBh    -5.793   1.0      0.0327      0.062300
# 09QIIA0zY0dqRoovbsCdxE   -11.592   0.0      0.0358      0.873000
#
#                         Instrumentalness  Liveness  Valence    Tempo  \
# ID
# 4qgDlkfqsbZ0q5tOSp0nqE          0.028600    0.0797   0.2800  107.977
# 3V417nSM4Ilh0Tt5CqustV          0.000111    0.2760   0.4810   86.953
# 1KuNk1ZZPTZKwjjo1Vdw9G          0.005180    0.1680   0.1390   120.05
# 1Qf8YGAWyajekT32SDCpbB          0.626000    0.3080   0.9430  130.023
# 02h7YFPYqyKtSx2eAwHmHZ          0.549000    0.0587   0.3330  199.948
# 5u3l2TONYacJgmRPQVaF9y          0.026000    0.0802   0.2780  191.014
# 1kRuXopX9SPHrvTp1kIvpO          0.000371    0.9260   0.2670  180.061
# 4SZymOV9M2wAz1N2uMWQUx          0.002490    0.4160   0.2760  107.031
# 1zt3Jjw4kyyMXdSSWQbLI5          0.000356    0.4030   0.0448  110.103
# 2JFnvk50eXQ5ukFCoUHgcr          0.085800    0.1660   0.3890  124.994
# 6AXaFon5l29UPFnDNr8u6i          0.000042    0.3770   0.2060  110.008
# 62LEQyUMcEv7YI2VAJdQ5Z          0.000000    0.0632   0.1570  100.057
# 0auFmAHLVYJqQ43ElC9XwH          0.000039    0.1970   0.2630  106.996
# 5xT2TAzbJf9kZkJh9qskwC          0.933000    0.7030   0.1290  105.195
# 4inaFfvPzYE2s1N0rrFEuY          0.026900    0.1300   0.1100  139.636
# 57RMsTZgk0UXn9jRLa950f          0.000000    0.1290   0.3020  105.287
# 0lxCFQuLwiKGsJOvcO7PxM          0.000336    0.3720   0.1340   114.99
# 5Fw8WbjW6ZWuMR6d9naYw5          0.000000    0.0632   0.1570  100.057
# 7LmyIBMl7ZCm17TBhzKb5Q          0.005140    0.1680   0.0396   92.917
# 0g2X8EDZHpFuhrlYyZXUDM          0.085800    0.1660   0.3890  124.994
# 3bd4MYlPc6EdfY8f0WnWcO          0.045100    0.0983   0.0376   89.994
# 0lmp8VSWPOyrlmYpjNNDhU          0.000000    0.4350   0.1380   129.98
# 4MCLjQ7QFmPWYtLBeJlMRz          0.000323    0.4050   0.0381  118.044
# 4hNJXoAQeBtpSUF5MZtzre          0.000000    0.3290   0.3620   90.012
# 4Q4xocsF5xlQDht25iHdkK          0.000080    0.1300   0.0630  114.984
# 3Mz5lXbMBK2tUmKAwAJwi1          0.064800    0.1170   0.1890  175.036
# 5XupNatXG7LmrOwr5ezxzp          0.000002    0.0726   0.2810   80.025
# 2wm1p0qitm58cywbMjb9tX          0.000000    0.1330   0.5670  120.058
# 06C7xapNmwIj7y5WA4LLuz          0.051200    0.2690   0.5410  109.503
# 5lizvEPQRY3P7KYVY434T2          0.000059    0.0808   0.8040  160.051
# ...                                  ...       ...      ...      ...
# 0vBF31MfEp7DDHHIfbxwIH          0.902000    0.1270   0.0329  105.758
# 1aa3A3F6b5FZFtXAhtrybK          0.939000    0.1100   0.0397   78.662
# 7gpL5CorPuYBthvZkPPFGd          0.846000    0.0895   0.0363   74.671
# 75D9esOK7ASfcREQAvbtql          0.960000    0.0905   0.0389   87.653
# 53sNuDhuyhtVTPNXbk4dEN          0.982000    0.1020   0.0385  140.096
# 30VnmNoXmeNMlDR6MxLP5U          0.889000    0.1120   0.0361   72.339
# 2IAZza3wdiTYT8QtO0hbLv          0.964000    0.1240   0.0381   91.988
# 0yyWxyeHt09K786RjTs6KH          0.833000    0.1280   0.0357  137.555
# 0bnRIsBDDT2GyEozHCOcie          0.957000    0.1080   0.0754  139.441
# 4zI7J4c58Br1tY10NDyhlR          0.919000    0.1110   0.0621   83.961
# 4bx9Lbbsb2VnHkxwqd3NQ1          0.771000    0.0985   0.0906     71.3
# 5NRhAVJrW5o4FK1OKKgbgQ          0.828000    0.1140   0.1310  134.992
# 3dKEGve9GLAg0q8REFQpgY          0.365000    0.0746   0.0285   97.535
# 6LnG3cueIxb0SpZP3AfdUw          0.838000    0.1090   0.1750   68.484
# 1CYtN9f8AgIbQpCbzCnMRq          0.838000    0.1100   0.0328   57.257
# 1VZmICoSKxQVj6DEOt0O0K          0.968000    0.1060   0.0383    80.96
# 23puVz6Rhiq8Wax9KxnZtW          0.930000    0.1080   0.0643  135.859
# 6l8Xxuu9DMIEzZqfvedNZA          0.787000    0.1090   0.0372   70.723
# 4RnDh1ovWF24qCsTma9pgV          0.950000    0.3290   0.0450   78.725
# 1uO9ZJFzDuwQ2XzmHt5TmN          0.761000    0.1040   0.0952   83.457
# 3O9i7hYrsLU99msJcjPOCL          0.749000    0.0971   0.0316  139.613
# 0IV0v2RIhevXsu9G0u82iP          0.768000    0.1040   0.0367  101.173
# 6jJkW2RUsOHCe4hiIk1tED          0.866000    0.1120   0.0895   91.814
# 3qEJ0eRAf40TTrofN7rmP7          0.796000    0.1040   0.0362  141.848
# 0SEmfr0lcljA3KFZtAxto4          0.912000    0.1100   0.0358   65.585
# 6uZqFdxRsSXgswqtKKBYK7          0.942000    0.1010   0.2180  132.111
# 0OLknAPE9i8CXou7d9Hk4M          0.821000    0.1150   0.0307   68.814
# 72lTBttLvsJ7FXLhualmIN          0.774000    0.0882   0.0362  130.417
# 2gjiQzZogB3fp4V7t9GKBh          0.000000    0.1780   0.9070  137.924
# 09QIIA0zY0dqRoovbsCdxE          0.037800    0.1670   0.2210  176.691
#
#                         Duration_ms time_signature        Genre
# ID
# 4qgDlkfqsbZ0q5tOSp0nqE     221507.0            4.0  celticmetal
# 3V417nSM4Ilh0Tt5CqustV     272292.0            4.0  celticmetal
# 1KuNk1ZZPTZKwjjo1Vdw9G     192000.0            3.0  celticmetal
# 1Qf8YGAWyajekT32SDCpbB     188400.0            4.0  celticmetal
# 02h7YFPYqyKtSx2eAwHmHZ     320687.0            4.0  celticmetal
# 5u3l2TONYacJgmRPQVaF9y     248747.0            4.0  celticmetal
# 1kRuXopX9SPHrvTp1kIvpO     179653.0            4.0  celticmetal
# 4SZymOV9M2wAz1N2uMWQUx     249240.0            4.0  celticmetal
# 1zt3Jjw4kyyMXdSSWQbLI5     261373.0            4.0  celticmetal
# 2JFnvk50eXQ5ukFCoUHgcr     200240.0            4.0  celticmetal
# 6AXaFon5l29UPFnDNr8u6i     240760.0            4.0  celticmetal
# 62LEQyUMcEv7YI2VAJdQ5Z     266267.0            4.0  celticmetal
# 0auFmAHLVYJqQ43ElC9XwH     240093.0            3.0  celticmetal
# 5xT2TAzbJf9kZkJh9qskwC     152213.0            4.0  celticmetal
# 4inaFfvPzYE2s1N0rrFEuY     402253.0            4.0  celticmetal
# 57RMsTZgk0UXn9jRLa950f     235080.0            4.0  celticmetal
# 0lxCFQuLwiKGsJOvcO7PxM     226293.0            4.0  celticmetal
# 5Fw8WbjW6ZWuMR6d9naYw5     266267.0            4.0  celticmetal
# 7LmyIBMl7ZCm17TBhzKb5Q     117307.0            1.0  celticmetal
# 0g2X8EDZHpFuhrlYyZXUDM     200240.0            4.0  celticmetal
# 3bd4MYlPc6EdfY8f0WnWcO     342733.0            4.0  celticmetal
# 0lmp8VSWPOyrlmYpjNNDhU     228333.0            4.0  celticmetal
# 4MCLjQ7QFmPWYtLBeJlMRz     200680.0            4.0  celticmetal
# 4hNJXoAQeBtpSUF5MZtzre     340800.0            4.0  celticmetal
# 4Q4xocsF5xlQDht25iHdkK     278987.0            4.0  celticmetal
# 3Mz5lXbMBK2tUmKAwAJwi1     317733.0            4.0  celticmetal
# 5XupNatXG7LmrOwr5ezxzp     308893.0            4.0  celticmetal
# 2wm1p0qitm58cywbMjb9tX     245813.0            4.0  celticmetal
# 06C7xapNmwIj7y5WA4LLuz     216760.0            3.0  celticmetal
# 5lizvEPQRY3P7KYVY434T2     202587.0            4.0  celticmetal
# ...                             ...            ...          ...
# 0vBF31MfEp7DDHHIfbxwIH     195937.0            1.0   meditation
# 1aa3A3F6b5FZFtXAhtrybK     184642.0            5.0   meditation
# 7gpL5CorPuYBthvZkPPFGd     138798.0            1.0   meditation
# 75D9esOK7ASfcREQAvbtql     177214.0            1.0   meditation
# 53sNuDhuyhtVTPNXbk4dEN     240000.0            5.0   meditation
# 30VnmNoXmeNMlDR6MxLP5U     192793.0            4.0   meditation
# 2IAZza3wdiTYT8QtO0hbLv     188592.0            4.0   meditation
# 0yyWxyeHt09K786RjTs6KH     171760.0            4.0   meditation
# 0bnRIsBDDT2GyEozHCOcie     204914.0            4.0   meditation
# 4zI7J4c58Br1tY10NDyhlR     220781.0            4.0   meditation
# 4bx9Lbbsb2VnHkxwqd3NQ1     175357.0            3.0   meditation
# 5NRhAVJrW5o4FK1OKKgbgQ     150702.0            3.0   meditation
# 3dKEGve9GLAg0q8REFQpgY     184931.0            3.0   meditation
# 6LnG3cueIxb0SpZP3AfdUw     106315.0            3.0   meditation
# 1CYtN9f8AgIbQpCbzCnMRq     197838.0            4.0   meditation
# 1VZmICoSKxQVj6DEOt0O0K     175263.0            4.0   meditation
# 23puVz6Rhiq8Wax9KxnZtW     161442.0            1.0   meditation
# 6l8Xxuu9DMIEzZqfvedNZA     193469.0            4.0   meditation
# 4RnDh1ovWF24qCsTma9pgV     230323.0            3.0   meditation
# 1uO9ZJFzDuwQ2XzmHt5TmN     189000.0            1.0   meditation
# 3O9i7hYrsLU99msJcjPOCL     186500.0            4.0   meditation
# 0IV0v2RIhevXsu9G0u82iP     144105.0            4.0   meditation
# 6jJkW2RUsOHCe4hiIk1tED     204910.0            1.0   meditation
# 3qEJ0eRAf40TTrofN7rmP7     151532.0            4.0   meditation
# 0SEmfr0lcljA3KFZtAxto4     162776.0            4.0   meditation
# 6uZqFdxRsSXgswqtKKBYK7     224981.0            4.0   meditation
# 0OLknAPE9i8CXou7d9Hk4M     202015.0            4.0   meditation
# 72lTBttLvsJ7FXLhualmIN     217933.0            3.0   meditation
# 2gjiQzZogB3fp4V7t9GKBh     201739.0            4.0     ranchera
# 09QIIA0zY0dqRoovbsCdxE     201693.0            4.0     ranchera
#
# [9737 rows x 15 columns]
# (121815, 15)

# %% [markdown]
# ### Spotify Connection and Data Supplementation
# ***
# <b>Now that the data is been read, we want to connect to Spotify and use the code to download the "genre" information using the track IDs from the data.
# ***
# To connect with Spotify we need to use the Spotipy library.
# Detailed instructions on connecting with Spotify can be found in the library's [website](https://spotipy.readthedocs.io/en/latest/?highlight=playlist#spotipy.client.Spotify.category_playlists)
# Documentation for the Spotify Web API can be found [here](https://developer.spotify.com/documentation/web-api/quick-start/)</b>

# %% [markdown]
# <h4>Summary on connecting with Spotify:</h4>
# <ol>
# <li> Create an account and register your test application.
# <li> Set up your Client ID and Secret, and set them up as environment variables in your local machine, from where you will run your application. There are other ways to dyanmically use your Client ID and Secret without setting them as environment variables. Read the documentation of the Spotify Web API and the spotipy client to explore other options.
# <li> Import and call the desired APIs to download the specific data that you need, as I have done in the examples (and final run) below.
# </ol>

# %%
### 1st method of connectivity. Through this method the credentials and are passed and the token is received, both implicitly. 
### Through this method, the token cannot be refreshed by us.
### Through this method, refreshing the token was not possible.

# Get the username from terminal
username = os.getlogin()
scope = 'user-library-read user-read-private'

# Erase cache and prompt for user permission
try : 
    token = util.prompt_for_user_token(username, scope)
except: 
    os.remove(f".cache-{username}")
    token = util.prompt_for_user_token(username, scope)
    
# Create Spotify object with permissions
spotifyObj = spotipy.Spotify(auth=token)

user = spotifyObj.current_user()

displayName = user['display_name']
followers = user['followers']['total']

print(displayName)
# Out:
# Harsha Neel

# %%
### 1st proof of concept before running through the entire data set - small number - first 4 items

# Getting the track IDs of a small set
trackIDs = df_cleaned.index[0:4]

# copy of cleaned df, with a small subset of data
df_copy = df_cleaned.iloc[0:4, :]

print("\n", trackIDs)
print("\n", type(trackIDs))
print("\n", trackIDs.shape)

# initializing lists to add as new columns later
artists = []
popularities = []

for trackID in trackIDs:
    
    track = spotifyObj.track(trackID)
    popularity = track['popularity']
    
    # The artist object comes back as a list of "artists", even for a single song - possibly due to collabs and feat. etc. between artists.
    # Looking through many examples, I found that only 1 artist would exist in the list, thereby leading to the assumption below.
    # Assumption - the main artist of the song will always be the first in the list. I think that's fair.
    artist = track['album']['artists'][0]['name']
    
    artists.append(artist)
    popularities.append(popularity)

    print(artist, ": ", popularity)

# Assign the new columns to the final form of the df.
df_final = df_copy.assign(Artists = artists, Popularity = popularities)


print("\n", df_final)
# Out:
#  Index(['6J2VvzKwWc2f0JP5RQVZjq', '4HA34COgxgVJ6zK88UN4Ik',
#        '3W6Xik6Xxf06JuUoZSATlD', '2gGveBaLJQMtJ43X4UL5kH'],
#       dtype='object', name='ID')
#
#  <class 'pandas.core.indexes.base.Index'>
#
#  (4,)
# The HU :  55
# Gloryhammer :  21
# Orion's Reign :  2
# Brothers of Metal :  50
#
#                                 Name  Danceability  Energy   Key  Loudness  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq   YuveYuveYu         0.624   0.857  10.0    -6.250
# 4HA34COgxgVJ6zK88UN4Ik  Gloryhammer         0.517   0.916   0.0    -4.933
# 3W6Xik6Xxf06JuUoZSATlD       Nostos         0.251   0.894   8.0    -4.103
# 2gGveBaLJQMtJ43X4UL5kH    Yggdrasil         0.469   0.743   1.0    -5.570
#
#                         Mode  Speechness  Acousticness  Instrumentalness  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq   0.0      0.0542      0.020800          0.206000
# 4HA34COgxgVJ6zK88UN4Ik   1.0      0.0559      0.000182          0.001910
# 3W6Xik6Xxf06JuUoZSATlD   0.0      0.0570      0.014400          0.000000
# 2gGveBaLJQMtJ43X4UL5kH   0.0      0.0272      0.002220          0.000111
#
#                         Liveness  Valence    Tempo  Duration_ms  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq     0.110    0.324  131.926     282920.0
# 4HA34COgxgVJ6zK88UN4Ik     0.306    0.444  135.996     300320.0
# 3W6Xik6Xxf06JuUoZSATlD     0.123    0.297  114.223     175353.0
# 2gGveBaLJQMtJ43X4UL5kH     0.276    0.481   86.953     272292.0
#
#                        time_signature        Genre            Artists  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq            4.0  celticmetal             The HU
# 4HA34COgxgVJ6zK88UN4Ik            4.0  celticmetal        Gloryhammer
# 3W6Xik6Xxf06JuUoZSATlD            4.0  celticmetal      Orion's Reign
# 2gGveBaLJQMtJ43X4UL5kH            4.0  celticmetal  Brothers of Metal
#
#                         Popularity
# ID
# 6J2VvzKwWc2f0JP5RQVZjq          55
# 4HA34COgxgVJ6zK88UN4Ik          21
# 3W6Xik6Xxf06JuUoZSATlD           2
# 2gGveBaLJQMtJ43X4UL5kH          50

# %% [markdown]
# <b> NOTE: This is the 2nd method of connectivity - where I explicitly supply the client credentials to the call and receive the token which I can actually refresh.
# ***
# The reason I'm using this method as the final one to download data is because of the token refresh possiblity. The token expires within a very short duration and getting data becomes a nuisance. So, to automate the token refresh process and continue downloading the data I need, I use this approach.</b>

# %%
### 2nd proof of concept before running through the entire data set - bigger number - first 2000 items


import time
import os
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

client_id_str = 'SPOTIPY_CLIENT_ID'
client_secret_str = 'SPOTIPY_CLIENT_SECRET'
client_uri_str = 'SPOTIPY_REDIRECT_URI'

client_id = os.getenv(client_id_str)
client_sec = os.getenv(client_secret_str)
client_uri = os.getenv(client_uri_str)

# Get the username from terminal
username = os.getlogin()
scopes = 'user-library-read user-read-private'

sp_oauth = SpotifyOAuth(client_id=client_id,client_secret=client_sec,redirect_uri=client_uri,scope=scopes)
token_info = sp_oauth.get_cached_token() 
if not token_info:
    auth_url = sp_oauth.get_authorize_url()
    print(auth_url)
    response = input('Paste the above link into your browser, then paste the redirect url here: ')

    code = sp_oauth.parse_response_code(response)
    token_info = sp_oauth.get_access_token(code)

    token = token_info['access_token']
    print("\nInitial token", token)

sp = spotipy.Spotify(auth=token)

def refresh():
    global token_info, sp

    #if SpotifyOAuth..is_token_expired(token_info):
    print("\nRefreshing token..")
    token_info = sp_oauth.refresh_access_token(token_info['refresh_token'])
    token = token_info['access_token']
    print("\nRefreshed token", token)
    sp = spotipy.Spotify(auth=token)


# Getting the track IDs of a small set
trackIDs = df_cleaned.index[0:2000]

# copy of cleaned df, with a small subset of data
df_copy = df_cleaned.iloc[0:2000, :]

counter = 0
limiter = 500

start = time.time()

print("\n", "no of track IDs: ", trackIDs.shape[0])

# initializing lists to add as new columns later
artists = []
popularities = []

#spotifyObj = spotifyConnect()

for trackID in trackIDs:
    
    track = sp.track(trackID)
    popularity = track['popularity']
    
    # The artist object comes back as a list of "artists", even for a single song - possibly due to collabs and feat. etc. between artists.
    # Looking through many examples, I found that only 1 artist would exist in the list, thereby leading to the assumption below.
    # Assumption - the main artist of the song will always be the first in the list. I think that's fair.
    artist = track['album']['artists'][0]['name']
    
    artists.append(artist)
    popularities.append(popularity)
    counter += 1
    
    if counter == limiter:
        
        counter = 0
        refresh()
        #spotifyConnect()
        #time.sleep(3)
      
     


    #print(artist, ": ", popularity)

# Assign the new columns to the final form of the df.
df_final = df_copy.assign(Artists = artists, Popularity = popularities)


end = time.time()

print("\n", df_final.head())

time_taken = end - start

print("time:", time_taken)

df_final.to_csv("2000ItemsFile.csv", sep=",")
# Out:
# https://accounts.spotify.com/authorize?client_id=da6d31d6cef1486ebc7707d2745e0535&response_type=code&redirect_uri=http%3A%2F%2Fgoogle.com%2F&scope=user-library-read+user-read-private
# Paste the above link into your browser, then paste the redirect url here: https://www.google.com/?code=AQAba3_G99PJzrufVDGxLtkTXpHkretQ5chGXi2caQETCxzKi9bzQHXmPMuuIa16cSTztQYM_r9kvi0gl1RmJn_GsIZPM9Q2PRQPLeSCjr_dvovOVeJnBXKLx2LO9cSNG-KKpjqXVin7aIDF4KtR498tVC-o7bZ2bGF1cPrkLY5NfrzMTGUNhKhxkg9375G0gZMTyGrTSgapoytn2hs42VeFEPST9i0ozkUyEzG8
#
# Initial token BQDYgLefgY8HNTgBbwgNweloMk-408x_7T99aKyq2CZWrtGwMSnf5i_1wSjhxS8fSpJq6palAO071aLyS0BRxpRbbPf349vQUZhEr-JQeaUDH60vJcfHw7_V4eOMkpVojMl3AtcEeKLz7cdgPN_0aN9fDd10KFrvEUs
#
#  no of track IDs:  2000
#
# Refreshing token..
#
# Refreshed token BQBLzvnv2pi4t52424ibxTg7ihtOo8OmsgSwbMpGo0PzmIOEqXNbRQQlUQLk6a_5Dp0Do7UQIh1fR6lZUcb5Bm9hrAs7OZj5CkXVzrIzZlt_6fUGTsUisCiC8pDljLm5wKSDjLoZxdcw0hfGAYEy7de1EPVNCd1UEnMZofye1w
#
# Refreshing token..
#
# Refreshed token BQC8e2gPH93mGzd4oME3MuGCHeb1kZwJsdSnVFcT4-QqlrdLnOxB-pOYKWAWeoLPU-O87x2bR5mW6l4q7O1M0mCNPPwqmMFpKaTvHMKyrMgOyEAJX8AXD8c1kgpkBO-Pn6vUj1AoetDEo6Lex_mLUyvK6nQq-ODRajSNlXrH2g
#
# Refreshing token..
#
# Refreshed token BQCREoTCXoTJzEgCoLf9cWmGznPimestw9Zc1NR-5qi_5yNKSxrlmbxLMAm8RQyztQNb0743LX2SJ2ALgVguWYgrScOtDppjo4nLvbiEsgp1mtxX40rfzdHabWbEt0nDBZrweT8c-YpHYXlEH2K0zHTc3jkAxS92sYqJZJNQBg
#
# Refreshing token..
#
# Refreshed token BQDIPvXGJIcrvem_HYIITK2VQmQT8K_BCW5L4vmOLmN6i1f5Vw4B-I9vBJVvOO6RqdskS5cyhKqsQ7XrACbW2eJCia99_QBFqT_IMWN5PK6uVo3GF8IIwZN38ajX9wLx5yKo2m301JoJqYm_EgwYAmiU3joqj1XDOrEIn6k2ZA
#
#                                  Name  Danceability  Energy   Key  Loudness  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq    YuveYuveYu         0.624   0.857  10.0    -6.250
# 4HA34COgxgVJ6zK88UN4Ik   Gloryhammer         0.517   0.916   0.0    -4.933
# 3W6Xik6Xxf06JuUoZSATlD        Nostos         0.251   0.894   8.0    -4.103
# 2gGveBaLJQMtJ43X4UL5kH     Yggdrasil         0.469   0.743   1.0    -5.570
# 1lRF81A1C9QoCgBcEop2zg  Incense&Iron         0.487   0.952   1.0    -4.429
#
#                         Mode  Speechness  Acousticness  Instrumentalness  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq   0.0      0.0542      0.020800          0.206000
# 4HA34COgxgVJ6zK88UN4Ik   1.0      0.0559      0.000182          0.001910
# 3W6Xik6Xxf06JuUoZSATlD   0.0      0.0570      0.014400          0.000000
# 2gGveBaLJQMtJ43X4UL5kH   0.0      0.0272      0.002220          0.000111
# 1lRF81A1C9QoCgBcEop2zg   0.0      0.0613      0.000228          0.000000
#
#                         Liveness  Valence    Tempo  Duration_ms  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq     0.110    0.324  131.926     282920.0
# 4HA34COgxgVJ6zK88UN4Ik     0.306    0.444  135.996     300320.0
# 3W6Xik6Xxf06JuUoZSATlD     0.123    0.297  114.223     175353.0
# 2gGveBaLJQMtJ43X4UL5kH     0.276    0.481   86.953     272292.0
# 1lRF81A1C9QoCgBcEop2zg     0.161    0.329  125.993     237933.0
#
#                        time_signature        Genre            Artists  \
# ID
# 6J2VvzKwWc2f0JP5RQVZjq            4.0  celticmetal             The HU
# 4HA34COgxgVJ6zK88UN4Ik            4.0  celticmetal        Gloryhammer
# 3W6Xik6Xxf06JuUoZSATlD            4.0  celticmetal      Orion's Reign
# 2gGveBaLJQMtJ43X4UL5kH            4.0  celticmetal  Brothers of Metal
# 1lRF81A1C9QoCgBcEop2zg            4.0  celticmetal          Powerwolf
#
#                         Popularity
# ID
# 6J2VvzKwWc2f0JP5RQVZjq          55
# 4HA34COgxgVJ6zK88UN4Ik          21
# 3W6Xik6Xxf06JuUoZSATlD           2
# 2gGveBaLJQMtJ43X4UL5kH          50
# 1lRF81A1C9QoCgBcEop2zg          22
# time: 339.56486201286316

# %% [markdown]
# <b>This is the final and proper run - for all the data. Not a test. Using the 2nd connect method. I will let it run to completion. And with the full run, it will merge the data at the end.
# There is an intermediate csv write process, further explained below.
# ***
# Note: There are several better ways to handle this instead of performing an expensive io operation to write all the intermediate data onto disk, but I had only kept this step during the test run process, but didn't end up removing it during the final run.</b>

# %%
### Final run - the entire data set - 121815 items

import time
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials


# env variables - previously set - which are required to establish an Oauth connection

# env variable keys
client_id_str = 'SPOTIPY_CLIENT_ID'
client_secret_str = 'SPOTIPY_CLIENT_SECRET'
client_uri_str = 'SPOTIPY_REDIRECT_URI'

# env variable values
client_id = os.getenv(client_id_str)
client_sec = os.getenv(client_secret_str)
client_uri = os.getenv(client_uri_str)

# Get the username from terminal
username = os.getlogin()
scopes = 'user-library-read user-read-private'

# Spotify connection logic. This was required to be brought into this cell 
# for repeated execution to retrieve the entire dataset without the authentication token expiring.

# creates an Oauth connection using the client credentials
sp_oauth = SpotifyOAuth(client_id=client_id,client_secret=client_sec,redirect_uri=client_uri,scope=scopes)
token_info = sp_oauth.get_cached_token() 
if not token_info:
    auth_url = sp_oauth.get_authorize_url()
    print(auth_url)
    response = input('Paste the above link into your browser, then paste the redirect url here: ')

    code = sp_oauth.parse_response_code(response)
    token_info = sp_oauth.get_access_token(code)

    token = token_info['access_token']
    #print("\nInitial token", token)

sp = spotipy.Spotify(auth=token)

def refresh():
    global token_info, sp

    #if SpotifyOAuth..is_token_expired(token_info):
    print("\nRefreshing token..")
    token_info = sp_oauth.refresh_access_token(token_info['refresh_token'])
    token = token_info['access_token']
    #print("Refreshed token", token)
    sp = spotipy.Spotify(auth=token)


# Getting the track IDs of a small set
trackIDs = df_cleaned.index

# counter for the spotify token refresh
counter = 0

# Once the "counter" reaches the "limiter" number - 800, the token refresh call will be made.
# i.e., it downloads 800 records before refreshing.
limiter = 800

# The refresh counter is simply for me to keep track of how many times the token has been "refreshed", 
# and that includes the first time (even though that's not techincally a "refresh")
refreshCounter = 1

start = time.time()

print("\n", "no of track IDs: ", trackIDs.shape[0])

# initializing lists to add as new columns later
artists = []
popularities = []
ids = []

for trackID in trackIDs:
    
    track = sp.track(trackID)
    popularity = track['popularity']
    
    # The artist object comes back as a list of "artists", even for a single song - possibly due to collabs and feat. etc. 
    # between artists. Looking through many examples, I found that only 1 artist would exist in the list, thereby leading
    # to the assumption below.
    # Assumption - the main artist of the song will always be the first in the list. I think that's fair.
    artist = track['album']['artists'][0]['name']
    
    ids.append(trackID)
    artists.append(artist)
    popularities.append(popularity)
    counter += 1
    
    
    # when counter reaches the limiter, the token will be refreshed
    if counter == limiter:
        data = {'ID':ids,'Artist':artists,'Popularity':popularities}
        df_temp = pd.DataFrame(data)
        
        # This csv write, is to capture the intermediate data in case, there is any other failure, so that I may see at what
        # record it stopped.
        filename = "temp" + str(refreshCounter) + ".csv"
        df_temp.to_csv(filename, sep=",")
        
        # The reason for using this appraoch is because even though Spotipy's documentation shows a method to check for the
        # token's expiry, it does not actually exist in the library, strangely. So, I need to make a periodic refresh, and 
        # it's always safe to use a smaller number for such cases.
        counter = 0
        refreshCounter += 1
        refresh()
    

# Assign the new columns to the final form of the df.
df_final = df_cleaned.assign(Artists = artists, Popularity = popularities)

print("\n", "Token refreshed a total of ", refreshCounter, " times")

end = time.time()

#print("\n", df_final.head())

time_taken = end - start

print("time (seconds):", time_taken)

df_final.to_csv("FinalData.csv", sep=",")
# Out:
# https://accounts.spotify.com/authorize?client_id=da6d31d6cef1486ebc7707d2745e0535&response_type=code&redirect_uri=http%3A%2F%2Fgoogle.com%2F&scope=user-library-read+user-read-private
# Paste the above link into your browser, then paste the redirect url here: https://www.google.com/?code=AQA1Aw1dFyjWVBdkjb4cfc4Tupir_6ptHywRlc8pZxTpa0evNmOSNj8uG3nvhwgwCuTAI7tDgfiB3xukZGB2x5GDsfB-6kAXUFVV1zqhu3FsM3I90LF9dgtC5mLDZAB9lVBv8yHyTQiiumCxTe6s_RTfE5IFe0KqxyntaeQuOoPEZVLTZAvvjOkGujL453_L66bOHRJIPxhGmdYBJANvil5r1KdV6jgtF5xNk_49
#
#  no of track IDs:  121815
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
# Refreshing token..
#
#  Token refreshed a total of  153  times
# time (seconds): 20561.576769828796

# %%
# Checking post-download 
df_final.info()

print(df_final.describe())

df_main = pd.read_csv("FinalData.csv", sep=",")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 121815 entries, 6J2VvzKwWc2f0JP5RQVZjq to 6XoNBGHoWlqMtSTob5heto
# Data columns (total 17 columns):
# Name                121815 non-null object
# Danceability        121815 non-null float64
# Energy              121815 non-null float64
# Key                 121815 non-null float64
# Loudness            121815 non-null float64
# Mode                121815 non-null float64
# Speechness          121815 non-null float64
# Acousticness        121815 non-null float64
# Instrumentalness    121815 non-null float64
# Liveness            121815 non-null float64
# Valence             121815 non-null float64
# Tempo               121815 non-null object
# Duration_ms         121815 non-null float64
# time_signature      121815 non-null object
# Genre               121815 non-null object
# Artists             121815 non-null object
# Popularity          121815 non-null int64
# dtypes: float64(11), int64(1), object(5)
# memory usage: 16.7+ MB
#         Danceability         Energy            Key       Loudness  \
# count  121815.000000  121815.000000  121815.000000  121815.000000
# mean        0.553010       0.648136       5.311636      -8.552146
# std         0.183783       0.246484       3.568876       4.808416
# min         0.000000       0.000000       0.000000     -60.000000
# 25%         0.430000       0.486000       2.000000     -10.408000
# 50%         0.566000       0.690000       5.000000      -7.398000
# 75%         0.693000       0.853000       9.000000      -5.354000
# max         0.988000       1.000000      11.000000       5.056000
#
#                 Mode     Speechness   Acousticness  Instrumentalness  \
# count  121815.000000  121815.000000  121815.000000     121815.000000
# mean        0.615860       0.083428       0.269310          0.236783
# std         0.486393       0.099538       0.323438          0.355855
# min         0.000000       0.000000       0.000000          0.000000
# 25%         0.000000       0.036100       0.007445          0.000002
# 50%         1.000000       0.048500       0.103000          0.001830
# 75%         1.000000       0.083200       0.483000          0.532000
# max         1.000000       0.966000       0.996000          0.999000
#
#             Liveness        Valence   Duration_ms     Popularity
# count  121815.000000  121815.000000  1.218150e+05  121815.000000
# mean        0.193199       0.466356  2.547858e+05      25.197660
# std         0.162382       0.265850  1.281630e+05      22.474276
# min         0.000000       0.000000  3.576000e+03       0.000000
# 25%         0.095000       0.242000  1.910670e+05       4.000000
# 50%         0.125000       0.455000  2.296000e+05      21.000000
# 75%         0.246000       0.679000  2.870710e+05      42.000000
# max         1.000000       1.000000  5.949886e+06      96.000000

# %% [markdown]
# <b>As we see, the data looks good. There are no warnings while trying to read the CSV file either.
# ***
# With this, the wrangling process has been completed.</b>
